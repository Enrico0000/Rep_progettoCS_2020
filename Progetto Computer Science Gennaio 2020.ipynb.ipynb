# %%
import pandas as pd
import datetime as dt

# %%
# punto 1
loans_lenders1 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[0:140000]
loans_lenders2 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[140000:280000]
loans_lenders3 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[280000:420000]
loans_lenders4 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[420000:560000]
loans_lenders5 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[560000:700000]
loans_lenders6 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[700000:840000]
loans_lenders7 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[840000:980000]
loans_lenders8 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[980000:1120000]
loans_lenders9 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                            error_bad_lines=False,
                            sep = ',',
                            low_memory = False,
                            warn_bad_lines=False)[1120000:1260000]
loans_lenders10 = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans_lenders.csv',
                              error_bad_lines=False,
                              sep = ',',
                              low_memory = False,
                              warn_bad_lines=False)[1260000:1400000]

# %%
lo_le1 = loans_lenders1.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders1 = loans_lenders1.join(lo_le1).drop('lenders', axis=1)
loans_lenders1 = loans_lenders1.set_index('loan_id')
loans_lenders1 = loans_lenders1.stack()
loans_lenders1 = pd.DataFrame(loans_lenders1)
loans_lenders1 = loans_lenders1.reset_index()

# %%
lo_le2 = loans_lenders2.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders2 = loans_lenders2.join(lo_le2).drop('lenders', axis=1)
loans_lenders2 = loans_lenders2.set_index('loan_id')
loans_lenders2 = loans_lenders2.stack()
loans_lenders2 = pd.DataFrame(loans_lenders2)
loans_lenders2 = loans_lenders2.reset_index()

# %%
lo_le3 = loans_lenders3.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders3 = loans_lenders3.join(lo_le3).drop('lenders', axis=1)
loans_lenders3 = loans_lenders3.set_index('loan_id')
loans_lenders3 = loans_lenders3.stack()
loans_lenders3 = pd.DataFrame(loans_lenders3)
loans_lenders3 = loans_lenders3.reset_index()

# %%
lo_le4 = loans_lenders4.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders4 = loans_lenders4.join(lo_le4).drop('lenders', axis=1)
loans_lenders4 = loans_lenders4.set_index('loan_id')
loans_lenders4 = loans_lenders4.stack()
loans_lenders4 = pd.DataFrame(loans_lenders4)
loans_lenders4 = loans_lenders4.reset_index()

# %%
lo_le5 = loans_lenders5.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders5 = loans_lenders5.join(lo_le5).drop('lenders', axis=1)
loans_lenders5 = loans_lenders5.set_index('loan_id')
loans_lenders5 = loans_lenders5.stack()
loans_lenders5 = pd.DataFrame(loans_lenders5)
loans_lenders5 = loans_lenders5.reset_index()

# %%
lo_le6 = loans_lenders6['lenders'].str.split(',' , expand = True)
loans_lenders6 = loans_lenders6.join(lo_le6).drop('lenders', axis=1)
loans_lenders6 = loans_lenders6.set_index('loan_id')
loans_lenders6 = loans_lenders6.stack()
loans_lenders6 = pd.DataFrame(loans_lenders6)
loans_lenders6 = loans_lenders6.reset_index()

# %%
lo_le7 = loans_lenders7.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders7 = loans_lenders7.join(lo_le7).drop('lenders', axis=1)
loans_lenders7 = loans_lenders7.set_index('loan_id')
loans_lenders7 = loans_lenders7.stack()
loans_lenders7 = pd.DataFrame(loans_lenders7)
loans_lenders7 = loans_lenders7.reset_index()

# %%
lo_le8 = loans_lenders8.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders8 = loans_lenders8.join(lo_le8).drop('lenders', axis=1)
loans_lenders8 = loans_lenders8.set_index('loan_id')
loans_lenders8 = loans_lenders8.stack()
loans_lenders8 = pd.DataFrame(loans_lenders8)
loans_lenders8 = loans_lenders8.reset_index()

# %%
lo_le9 = loans_lenders9.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders9 = loans_lenders9.join(lo_le9).drop('lenders', axis=1)
loans_lenders9 = loans_lenders9.set_index('loan_id')
loans_lenders9 = loans_lenders9.stack()
loans_lenders9 = pd.DataFrame(loans_lenders9)
loans_lenders9 = loans_lenders9.reset_index()

# %%
lo_le10 = loans_lenders10.loc[:,'lenders'].str.split(',' , expand = True)
loans_lenders10 = loans_lenders10.join(lo_le10).drop('lenders', axis=1)
loans_lenders10 = loans_lenders10.set_index('loan_id')
loans_lenders10 = loans_lenders10.stack()
loans_lenders10 = pd.DataFrame(loans_lenders10)
loans_lenders10 = loans_lenders10.reset_index()

# %%
loans_lenders = pd.concat([loans_lenders1,loans_lenders2,loans_lenders3,loans_lenders4,
                           loans_lenders5,loans_lenders6,loans_lenders7,loans_lenders8,
                           loans_lenders9,loans_lenders10])

# %%
loans_lenders
#loans_lenders.to_csv('out.csv')
#Cancellare le loans_lenders parziali
# Out:
#          loan_id  level_1                   0
# 0         483693        0              muc888
# 1         483693        1             sam4326
# 2         483693        2         camaran3922
# 3         483693        3         lachheb1865
# 4         483693        4         rebecca3499
# 5         483693        5       karlheinz4543
# 6         483693        6             jerrydb
# 7         483693        7           paula8951
# 8         483693        8                gmct
# 9         483693        9            amra9383
# 10        483693       10               r3922
# 11        483693       11           brian9451
# 12        483693       12           shree8053
# 13        483693       13            alan5513
# 14        483693       14           oisin3389
# 15        483693       15           helle8622
# 16        483693       16              bo3186
# 17        483693       17             ric8947
# 18        483693       18      daniel98469874
# ...

# %%
## punto 2
loans = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\loans.csv',
                    parse_dates = True,
                    infer_datetime_format = True)
loans['disburse_time'] = pd.to_datetime(loans['disburse_time'])
#loans['disburse_time'] = loans['disburse_time'].dt.date
#loans['disburse_time'].head()
loans['planned_expiration_time'] = pd.to_datetime(loans['planned_expiration_time'])
#loans['planned_expiration_time'] = loans['planned_expiration_time'].dt.date
#loans['planned_expiration_time'].head()
loans['raised_time'] = pd.to_datetime(loans['raised_time'])
#loans['raised_time'] = loans['raised_time'].dt.date
#loans['raised_time'].head()
loans['posted_time'] = pd.to_datetime(loans['posted_time'])
#loans['posted_time'] = loans['posted_time'].dt.date
#loans['posted_time'].head()
loans['duration'] = loans['planned_expiration_time'] - loans['disburse_time']
loans['duration'] = loans['duration'].dt.days
#loans['duration'].head()

# %%
## punto 3
(loans_lenders.groupby(0)[0].count() >= 2).notnull()
# Out:
# 0
#  000               True
#  00000             True
#  0002              True
#  00mike00          True
#  0101craign0101    True
#  0132575           True
#  0154884           True
#  0161130           True
#  0169713           True
#  0185429           True
#  0197462           True
#  0206338           True
#  0219854           True
#  0221581           True
#  0239059           True
#  0245597           True
#  0256321           True
#  0265562           True
#  0279282           True
#  0288537           True
#  0295920           True
#  0307987           True
#  0312857           True
#  0321212           True
#  0326lsw           True
#  0332772           True
#  0346439           True
#  0353400           True
#  0367630           True
#  0376099           True
#                    ...
# zuzana5790         True
# zuzana7522         True
# zuzana8241         True
# zuzana8342         True
# zuzana9270         True
# zuzana9580         True
# zuzana9848         True
# ...

# %%
## punto 4
loans.groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                               2337
# Albania                                   3075
# Armenia                                  13952
# Azerbaijan                               10172
# Belize                                     218
# Benin                                     5946
# Bhutan                                       2
# Bolivia                                  25250
# Bosnia and Herzegovina                     608
# Botswana                                     1
# Brazil                                     482
# Bulgaria                                   296
# Burkina Faso                              3489
# Burundi                                   1727
# Cambodia                                 79701
# Cameroon                                  5085
# Canada                                       1
# Chad                                        61
# Chile                                      892
# China                                      134
# ...

# %%
## punto 5
loans.groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              1967950.0
# Albania                                  4307350.0
# Armenia                                 22950475.0
# Azerbaijan                              14784625.0
# Belize                                    150175.0
# Benin                                    3865825.0
# Bhutan                                     20000.0
# Bolivia                                 44226725.0
# Bosnia and Herzegovina                    477250.0
# Botswana                                    8000.0
# Brazil                                   1192325.0
# Bulgaria                                  375300.0
# Burkina Faso                             4085200.0
# Burundi                                  5233450.0
# Cambodia                                51613525.0
# Cameroon                                 2250800.0
# Canada                                     50000.0
# Chad                                       20075.0
# ...

# %%
## punto 6
loans.groupby('country_name')['loan_amount'].sum()*100/loans.groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                             0.166573
# Albania                                 0.364586
# Armenia                                 1.942589
# Azerbaijan                              1.251410
# Belize                                  0.012711
# Benin                                   0.327214
# Bhutan                                  0.001693
# Bolivia                                 3.743468
# Bosnia and Herzegovina                  0.040396
# Botswana                                0.000677
# Brazil                                  0.100922
# Bulgaria                                0.031766
# Burkina Faso                            0.345782
# Burundi                                 0.442973
# Cambodia                                4.368706
# Cameroon                                0.190514
# Canada                                  0.004232
# Chad                                    0.001699
# Chile                                   0.219726
# ...

# %%
## punto 7, riferimento punto 4
loans[(loans['disburse_time'] >= '2005-01-01') & (loans['disburse_time'] <= '2005-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Bulgaria      3
# Cambodia      2
# Ecuador      10
# Gaza          8
# Honduras     72
# Kenya        40
# Nicaragua     6
# Senegal       3
# Tanzania      5
# Uganda       54
# Name: country_name, dtype: int64

# %%
loans[(loans['disburse_time'] >= '2006-01-01') & (loans['disburse_time'] <= '2006-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Azerbaijan     17
# Bulgaria       67
# Cambodia       58
# Ecuador       248
# Ghana          27
# Honduras      272
# Kenya         421
# Mexico        284
# Moldova        31
# Mozambique     16
# Nicaragua       5
# Nigeria        99
# Samoa          12
# Senegal        52
# Tanzania       69
# Togo           91
# Uganda        363
# Name: country_name, dtype: int64

# %%
loans[(loans['disburse_time'] >= '2007-01-01') & (loans['disburse_time'] <= '2007-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                              408
# Azerbaijan                              2126
# Bolivia                                  565
# Bulgaria                                 190
# Cambodia                                1615
# Cameroon                                 214
# Chad                                      61
# Cote D'Ivoire                            192
# Dominican Republic                       476
# Ecuador                                 1299
# Ghana                                    646
# Guatemala                                173
# Haiti                                     26
# Honduras                                 663
# Indonesia                                723
# Iraq                                     111
# Kenya                                   2224
# Lebanon                                  168
# Mexico                                  2444
# Moldova                                   57
# ...

# %%
loans[(loans['disburse_time'] >= '2008-01-01') & (loans['disburse_time'] <= '2008-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                              367
# Azerbaijan                              1408
# Benin                                    490
# Bolivia                                 1481
# Bosnia and Herzegovina                   537
# Bulgaria                                  33
# Cambodia                                6997
# Cameroon                                 205
# Cote D'Ivoire                             35
# Dominican Republic                      1213
# Ecuador                                  355
# El Salvador                               84
# Ghana                                   2389
# Guatemala                                270
# Haiti                                      8
# Honduras                                 124
# Indonesia                               1004
# Iraq                                      53
# Kenya                                    451
# Lebanon                                  818
# ...

# %%
loans[(loans['disburse_time'] >= '2009-01-01') & (loans['disburse_time'] <= '2009-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                               678
# Armenia                                    51
# Azerbaijan                                929
# Benin                                     983
# Bolivia                                  2586
# Bosnia and Herzegovina                     71
# Cambodia                                 6622
# Cameroon                                  192
# Chile                                       7
# Colombia                                   19
# Costa Rica                                229
# Dominican Republic                        597
# Ecuador                                   467
# El Salvador                              1291
# Ghana                                    5204
# Guatemala                                 461
# Haiti                                      27
# Honduras                                  616
# Indonesia                                 206
# Iraq                                       29
# ...

# %%
loans[(loans['disburse_time'] >= '2010-01-01') & (loans['disburse_time'] <= '2010-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                               632
# Armenia                                   347
# Azerbaijan                                760
# Benin                                    1016
# Bolivia                                  2570
# Burundi                                    53
# Cambodia                                 7146
# Cameroon                                   99
# Chile                                     137
# Colombia                                  653
# Congo                                     168
# Costa Rica                                631
# Dominican Republic                        684
# Ecuador                                  3739
# El Salvador                              1635
# Ghana                                    1709
# Guatemala                                 605
# Haiti                                      16
# Honduras                                  810
# Indonesia                                  89
# ...

# %%
loans[(loans['disburse_time'] >= '2011-01-01') & (loans['disburse_time'] <= '2011-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                               247
# Armenia                                   856
# Azerbaijan                                961
# Benin                                    1006
# Bolivia                                  2534
# Burkina Faso                              137
# Burundi                                   191
# Cambodia                                 5736
# Cameroon                                   96
# Chile                                     314
# Colombia                                 2151
# Congo                                     324
# Costa Rica                                673
# Dominican Republic                        424
# Ecuador                                  4333
# El Salvador                              3609
# Georgia                                   530
# Ghana                                    1691
# Guatemala                                 906
# Haiti                                      43
# ...

# %%
loans[(loans['disburse_time'] >= '2012-01-01') & (loans['disburse_time'] <= '2012-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Albania                                   332
# Armenia                                   976
# Azerbaijan                                969
# Benin                                    1507
# Bolivia                                  2558
# Burkina Faso                              254
# Burundi                                   230
# Cambodia                                 6174
# Cameroon                                  664
# Chile                                     324
# Colombia                                 3154
# Congo                                     199
# Costa Rica                                703
# Dominican Republic                        335
# Ecuador                                  4493
# El Salvador                              5504
# Georgia                                  1403
# Ghana                                    2079
# Guam                                        1
# Guatemala                                 995
# ...

# %%
loans[(loans['disburse_time'] >= '2013-01-01') & (loans['disburse_time'] <= '2013-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Albania                                   507
# Armenia                                  2276
# Azerbaijan                               1058
# Belize                                     78
# Benin                                     447
# Bolivia                                  3017
# Botswana                                    1
# Brazil                                     11
# Burkina Faso                              290
# Burundi                                   410
# Cambodia                                 4751
# Cameroon                                  715
# Chile                                     100
# Colombia                                 3110
# Congo                                     133
# Costa Rica                                706
# Cote D'Ivoire                              47
# Dominican Republic                        305
# Ecuador                                  2711
# El Salvador                              7739
# ...

# %%
loans[(loans['disburse_time'] >= '2014-01-01') & (loans['disburse_time'] <= '2014-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Albania                                   603
# Armenia                                  1968
# Azerbaijan                                986
# Belize                                    109
# Benin                                     496
# Bolivia                                  2613
# Brazil                                     50
# Burkina Faso                              407
# Burundi                                   370
# Cambodia                                 6245
# Cameroon                                  241
# Chile                                       4
# China                                      10
# Colombia                                 5335
# Congo                                      97
# Costa Rica                                454
# Dominican Republic                        153
# Ecuador                                  2951
# Egypt                                      46
# El Salvador                             13028
# ...

# %%
loans[(loans['disburse_time'] >= '2015-01-01') & (loans['disburse_time'] <= '2015-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                                 1
# Albania                                   638
# Armenia                                  2534
# Azerbaijan                                659
# Bolivia                                  2956
# Brazil                                     38
# Burkina Faso                              653
# Burundi                                   279
# Cambodia                                 7532
# Cameroon                                   96
# Chile                                       2
# China                                      63
# Colombia                                 6728
# Congo                                      31
# Costa Rica                                551
# Dominican Republic                        136
# Ecuador                                  2774
# Egypt                                     432
# El Salvador                             11939
# Georgia                                  1022
# ...

# %%
loans[(loans['disburse_time'] >= '2016-01-01') & (loans['disburse_time'] <= '2016-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Afghanistan                                 1
# Albania                                   475
# Armenia                                  2902
# Azerbaijan                                288
# Belize                                     23
# Bolivia                                  2483
# Brazil                                    110
# Burkina Faso                              876
# Burundi                                   167
# Cambodia                                11593
# Cameroon                                  797
# China                                      51
# Colombia                                 7138
# Costa Rica                                334
# Dominican Republic                        134
# Ecuador                                  5086
# Egypt                                     640
# El Salvador                              9282
# Georgia                                   550
# Ghana                                    1433
# ...

# %%
loans[(loans['disburse_time'] >= '2017-01-01') & (loans['disburse_time'] <= '2017-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Albania                                   520
# Armenia                                  2042
# Benin                                       1
# Bhutan                                      2
# Bolivia                                  1862
# Brazil                                    272
# Burkina Faso                              872
# Burundi                                    25
# Cambodia                                15160
# Cameroon                                 1738
# Canada                                      1
# China                                       9
# Colombia                                 5377
# Costa Rica                                397
# Cote D'Ivoire                               1
# Dominican Republic                        184
# Ecuador                                  4991
# Egypt                                    1342
# El Salvador                              9870
# Georgia                                   358
# ...

# %%
loans[(loans['disburse_time'] >= '2018-01-01') & (loans['disburse_time'] <= '2018-12-31')].groupby('country_name')['country_name'].count()
# Out:
# country_name
# Belize                                8
# Bolivia                              11
# Brazil                                1
# Cameroon                             27
# Colombia                             10
# Costa Rica                            1
# Dominican Republic                    2
# Ghana                                67
# Guatemala                             1
# Haiti                                17
# India                                 1
# Indonesia                             3
# Kenya                               587
# Kyrgyzstan                            1
# Lao People's Democratic Republic     19
# Malawi                                2
# Mali                                  1
# Mexico                                5
# Moldova                               5
# Mozambique                           26
# Nicaragua                             7
# Nigeria                              10
# Pakistan                              6
# ...

# %%
# punto 7, riferimento punto 5
loans[(loans['disburse_time'] >= '2005-01-01') & (loans['disburse_time'] <= '2005-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Bulgaria      1850.0
# Cambodia      1625.0
# Ecuador       5000.0
# Gaza          5000.0
# Honduras     33300.0
# Kenya        21350.0
# Nicaragua     3300.0
# Senegal       3225.0
# Tanzania      2300.0
# Uganda       25900.0
# Name: loan_amount, dtype: float64

# %%
loans[(loans['disburse_time'] >= '2006-01-01') & (loans['disburse_time'] <= '2006-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Azerbaijan     11700.0
# Bulgaria       79950.0
# Cambodia       41950.0
# Ecuador       149325.0
# Ghana          22325.0
# Honduras       94325.0
# Kenya         211775.0
# Mexico        189750.0
# Moldova        20925.0
# Mozambique     15950.0
# Nicaragua       3850.0
# Nigeria        45750.0
# Samoa           6800.0
# Senegal        49675.0
# Tanzania       45200.0
# Togo           74150.0
# Uganda        275975.0
# Name: loan_amount, dtype: float64

# %%
loans[(loans['disburse_time'] >= '2007-01-01') & (loans['disburse_time'] <= '2007-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              194975.0
# Azerbaijan                              1886525.0
# Bolivia                                  304700.0
# Bulgaria                                 263050.0
# Cambodia                                1111875.0
# Cameroon                                 116650.0
# Chad                                      20075.0
# Cote D'Ivoire                            182375.0
# Dominican Republic                       242775.0
# Ecuador                                  944575.0
# Ghana                                    548725.0
# Guatemala                                121825.0
# Haiti                                     26250.0
# Honduras                                 233750.0
# Indonesia                                125550.0
# Iraq                                     127200.0
# Kenya                                   1211500.0
# Lebanon                                  147400.0
# ...

# %%
loans[(loans['disburse_time'] >= '2008-01-01') & (loans['disburse_time'] <= '2008-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              362400.0
# Azerbaijan                              1395475.0
# Benin                                    222025.0
# Bolivia                                 1847275.0
# Bosnia and Herzegovina                   404450.0
# Bulgaria                                  25750.0
# Cambodia                                4821475.0
# Cameroon                                 120450.0
# Cote D'Ivoire                             35600.0
# Dominican Republic                      1074800.0
# Ecuador                                  301150.0
# El Salvador                               54275.0
# Ghana                                   1302125.0
# Guatemala                                509900.0
# Haiti                                     15825.0
# Honduras                                 106325.0
# Indonesia                                271725.0
# Iraq                                      63000.0
# ...

# %%
loans[(loans['disburse_time'] >= '2009-01-01') & (loans['disburse_time'] <= '2009-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              585125.0
# Armenia                                   91000.0
# Azerbaijan                              1598625.0
# Benin                                    343325.0
# Bolivia                                 4331425.0
# Bosnia and Herzegovina                    72800.0
# Cambodia                                4991050.0
# Cameroon                                  89700.0
# Chile                                     18000.0
# Colombia                                  14300.0
# Costa Rica                               211050.0
# Dominican Republic                      1054200.0
# Ecuador                                  425025.0
# El Salvador                             1053275.0
# Ghana                                   3179650.0
# Guatemala                                386225.0
# Haiti                                     80700.0
# Honduras                                 398825.0
# ...

# %%
loans[(loans['disburse_time'] >= '2010-01-01') & (loans['disburse_time'] <= '2010-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              563350.0
# Armenia                                  731875.0
# Azerbaijan                              1408775.0
# Benin                                    339550.0
# Bolivia                                 3104875.0
# Burundi                                  191975.0
# Cambodia                                5836975.0
# Cameroon                                  52025.0
# Chile                                    281550.0
# Colombia                                 540675.0
# Congo                                     92075.0
# Costa Rica                               609275.0
# Dominican Republic                      1443200.0
# Ecuador                                 3309975.0
# El Salvador                             1087775.0
# Ghana                                    846125.0
# Guatemala                                644150.0
# Haiti                                     38000.0
# ...

# %%
loans[(loans['disburse_time'] >= '2011-01-01') & (loans['disburse_time'] <= '2011-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                              245125.0
# Armenia                                 1820075.0
# Azerbaijan                              1753900.0
# Benin                                    829700.0
# Bolivia                                 2797775.0
# Burkina Faso                              97100.0
# Burundi                                  657025.0
# Cambodia                                4350525.0
# Cameroon                                  51975.0
# Chile                                    611950.0
# Colombia                                1462550.0
# Congo                                    229625.0
# Costa Rica                               614975.0
# Dominican Republic                      1121875.0
# Ecuador                                 4024450.0
# El Salvador                             2131900.0
# Georgia                                  524725.0
# Ghana                                    742125.0
# ...

# %%
loans[(loans['disburse_time'] >= '2012-01-01') & (loans['disburse_time'] <= '2012-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Albania                                  413000.0
# Armenia                                 2049625.0
# Azerbaijan                              1691225.0
# Benin                                   1245700.0
# Bolivia                                 3851200.0
# Burkina Faso                             278225.0
# Burundi                                  736250.0
# Cambodia                                4410125.0
# Cameroon                                 266575.0
# Chile                                   1153975.0
# Colombia                                2667500.0
# Congo                                    582475.0
# Costa Rica                               908700.0
# Dominican Republic                       881825.0
# Ecuador                                 5364900.0
# El Salvador                             3262500.0
# Georgia                                 1669600.0
# Ghana                                    995725.0
# ...

# %%
loans[(loans['disburse_time'] >= '2013-01-01') & (loans['disburse_time'] <= '2013-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Albania                                  786950.0
# Armenia                                 4131300.0
# Azerbaijan                              2161850.0
# Belize                                    27825.0
# Benin                                    366575.0
# Bolivia                                 5476650.0
# Botswana                                   8000.0
# Brazil                                    15350.0
# Burkina Faso                             321925.0
# Burundi                                 1093950.0
# Cambodia                                3598325.0
# Cameroon                                 297775.0
# Chile                                    407875.0
# Colombia                                3066300.0
# Congo                                    574925.0
# Costa Rica                               921675.0
# Cote D'Ivoire                             69425.0
# Dominican Republic                      1020525.0
# ...

# %%
loans[(loans['disburse_time'] >= '2014-01-01') & (loans['disburse_time'] <= '2014-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Albania                                   902550.0
# Armenia                                  3280025.0
# Azerbaijan                               1662325.0
# Belize                                    107625.0
# Benin                                     468950.0
# Bolivia                                  4997400.0
# Brazil                                     66200.0
# Burkina Faso                              512400.0
# Burundi                                  1096725.0
# Cambodia                                 4339625.0
# Cameroon                                  119900.0
# Chile                                      19250.0
# China                                      24200.0
# Colombia                                 4649125.0
# Congo                                     587225.0
# Costa Rica                                570525.0
# Dominican Republic                        757625.0
# Ecuador                                  4013675.0
# ...

# %%
loans[(loans['disburse_time'] >= '2015-01-01') & (loans['disburse_time'] <= '2015-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                                 6000.0
# Albania                                   844375.0
# Armenia                                  3519825.0
# Azerbaijan                                864200.0
# Bolivia                                  6829250.0
# Brazil                                     50950.0
# Burkina Faso                              874975.0
# Burundi                                   867950.0
# Cambodia                                 5054475.0
# Cameroon                                   46150.0
# Chile                                      84925.0
# China                                     155350.0
# Colombia                                 4274650.0
# Congo                                     199025.0
# Costa Rica                                762800.0
# Dominican Republic                        634075.0
# Ecuador                                  3188150.0
# Egypt                                     347600.0
# ...

# %%
loans[(loans['disburse_time'] >= '2016-01-01') & (loans['disburse_time'] <= '2016-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Afghanistan                                 8000.0
# Albania                                   639025.0
# Armenia                                  4357525.0
# Azerbaijan                                339775.0
# Belize                                     10525.0
# Bolivia                                  5876250.0
# Brazil                                    312450.0
# Burkina Faso                             1072075.0
# Burundi                                   508600.0
# Cambodia                                 5421775.0
# Cameroon                                  306525.0
# China                                     125925.0
# Colombia                                 3871250.0
# Costa Rica                                483125.0
# Dominican Republic                        460925.0
# Ecuador                                  4898800.0
# Egypt                                     507375.0
# El Salvador                              6332100.0
# ...

# %%
loans[(loans['disburse_time'] >= '2017-01-01') & (loans['disburse_time'] <= '2017-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Albania                                   721450.0
# Armenia                                  2969225.0
# Benin                                      50000.0
# Bhutan                                     20000.0
# Bolivia                                  4787800.0
# Brazil                                    724875.0
# Burkina Faso                              928500.0
# Burundi                                    70300.0
# Cambodia                                 7592200.0
# Cameroon                                  730600.0
# Canada                                     50000.0
# China                                      72000.0
# Colombia                                 3062625.0
# Costa Rica                                557725.0
# Cote D'Ivoire                              50000.0
# Dominican Republic                        580825.0
# Ecuador                                  5393025.0
# Egypt                                     525300.0
# ...

# %%
loans[(loans['disburse_time'] >= '2018-01-01') & (loans['disburse_time'] <= '2018-12-31')].groupby('country_name')['loan_amount'].sum()
# Out:
# country_name
# Belize                                4200.0
# Bolivia                               8725.0
# Brazil                               22500.0
# Cameroon                             52150.0
# Colombia                              5000.0
# Costa Rica                            1550.0
# Dominican Republic                    9850.0
# Ghana                                74675.0
# Guatemala                             3500.0
# Haiti                                32950.0
# India                                20000.0
# Indonesia                             3450.0
# Kenya                               393350.0
# Kyrgyzstan                            8000.0
# Lao People's Democratic Republic      6075.0
# Malawi                                2100.0
# Mali                                 50000.0
# Mexico                                 475.0
# Moldova                              15675.0
# Mozambique                           53850.0
# ...

# %%
# punto 7, riferimento punto 6
loans[(loans['disburse_time'] >= '2005-01-01') & (loans['disburse_time'] <= '2005-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2005-01-01') & (loans['disburse_time'] < '2005-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Bulgaria      1.798736
# Cambodia      1.579971
# Ecuador       4.861449
# Gaza          4.861449
# Honduras     32.377248
# Kenya        20.758386
# Nicaragua     3.208556
# Senegal       3.135634
# Tanzania      2.236266
# Uganda       25.182304
# Name: loan_amount, dtype: float64

# %%
loans[(loans['disburse_time'] >= '2006-01-01') & (loans['disburse_time'] <= '2006-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2006-01-01') & (loans['disburse_time'] < '2006-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Azerbaijan     0.873542
# Bulgaria       5.969202
# Cambodia       3.132058
# Ecuador       11.148857
# Ghana          1.666822
# Honduras       7.042464
# Kenya         15.811479
# Mexico        14.167056
# Moldova        1.562296
# Mozambique     1.190854
# Nicaragua      0.287448
# Nigeria        3.415772
# Samoa          0.507699
# Senegal        3.708819
# Tanzania       3.374708
# Togo           5.536164
# Uganda        20.604760
# Name: loan_amount, dtype: float64

# %%
loans[(loans['disburse_time'] >= '2007-01-01') & (loans['disburse_time'] <= '2007-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2007-01-01') & (loans['disburse_time'] < '2007-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                              1.268289
# Azerbaijan                              12.271618
# Bolivia                                  1.982037
# Bulgaria                                 1.711109
# Cambodia                                 7.232613
# Cameroon                                 0.758794
# Chad                                     0.130585
# Cote D'Ivoire                            1.186327
# Dominican Republic                       1.579222
# Ecuador                                  6.144347
# Ghana                                    3.569390
# Guatemala                                0.792457
# Haiti                                    0.170753
# Honduras                                 1.520516
# Indonesia                                0.816688
# Iraq                                     0.827421
# Kenya                                    7.880661
# Lebanon                                  0.958819
# ...

# %%
loans[(loans['disburse_time'] >= '2008-01-01') & (loans['disburse_time'] <= '2008-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2008-01-01') & (loans['disburse_time'] < '2008-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                              0.920086
# Azerbaijan                               3.542928
# Benin                                    0.563692
# Bolivia                                  4.689988
# Bosnia and Herzegovina                   1.026845
# Bulgaria                                 0.065376
# Cambodia                                12.241091
# Cameroon                                 0.305807
# Cote D'Ivoire                            0.090384
# Dominican Republic                       2.728776
# Ecuador                                  0.764580
# El Salvador                              0.137797
# Ghana                                    3.305924
# Guatemala                                1.294569
# Haiti                                    0.040178
# Honduras                                 0.269945
# Indonesia                                0.689874
# Iraq                                     0.159949
# ...

# %%
loans[(loans['disburse_time'] >= '2009-01-01') & (loans['disburse_time'] <= '2009-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2009-01-01') & (loans['disburse_time'] < '2005-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                             inf
# Armenia                                 inf
# Azerbaijan                              inf
# Benin                                   inf
# Bolivia                                 inf
# Bosnia and Herzegovina                  inf
# Cambodia                                inf
# Cameroon                                inf
# Chile                                   inf
# Colombia                                inf
# Costa Rica                              inf
# Dominican Republic                      inf
# Ecuador                                 inf
# El Salvador                             inf
# Ghana                                   inf
# Guatemala                               inf
# Haiti                                   inf
# Honduras                                inf
# Indonesia                               inf
# Iraq                                    inf
# Kenya                                   inf
# ...

# %%
loans[(loans['disburse_time'] >= '2010-01-01') & (loans['disburse_time'] <= '2010-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2010-01-01') & (loans['disburse_time'] < '2010-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                             0.776432
# Armenia                                 1.008700
# Azerbaijan                              1.941631
# Benin                                   0.467982
# Bolivia                                 4.279265
# Burundi                                 0.264588
# Cambodia                                8.044756
# Cameroon                                0.071703
# Chile                                   0.388044
# Colombia                                0.745180
# Congo                                   0.126901
# Costa Rica                              0.839728
# Dominican Republic                      1.989077
# Ecuador                                 4.561942
# El Salvador                             1.499216
# Ghana                                   1.166164
# Guatemala                               0.887794
# Haiti                                   0.052373
# Honduras                                0.727194
# ...

# %%
loans[(loans['disburse_time'] >= '2011-01-01') & (loans['disburse_time'] <= '2011-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2011-01-01') & (loans['disburse_time'] < '2011-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                             0.261713
# Armenia                                 1.943242
# Azerbaijan                              1.872588
# Benin                                   0.885847
# Bolivia                                 2.987104
# Burkina Faso                            0.103671
# Burundi                                 0.701487
# Cambodia                                4.644930
# Cameroon                                0.055492
# Chile                                   0.653361
# Colombia                                1.561522
# Congo                                   0.245164
# Costa Rica                              0.656591
# Dominican Republic                      1.197794
# Ecuador                                 4.296789
# El Salvador                             2.276168
# Georgia                                 0.560234
# Ghana                                   0.792345
# Guatemala                               0.999527
# ...

# %%
loans[(loans['disburse_time'] >= '2012-01-01') & (loans['disburse_time'] <= '2012-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2012-01-01') & (loans['disburse_time'] < '2012-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Albania                                 0.344639
# Armenia                                 1.710366
# Azerbaijan                              1.411289
# Benin                                   1.039509
# Bolivia                                 3.213740
# Burkina Faso                            0.232173
# Burundi                                 0.614384
# Cambodia                                3.680151
# Cameroon                                0.222451
# Chile                                   0.962966
# Colombia                                2.225969
# Congo                                   0.486062
# Costa Rica                              0.758290
# Dominican Republic                      0.735863
# Ecuador                                 4.476889
# El Salvador                             2.722483
# Georgia                                 1.393244
# Ghana                                   0.830910
# Guam                                    0.004172
# ...

# %%
loans[(loans['disburse_time'] >= '2013-01-01') & (loans['disburse_time'] <= '2013-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2013-01-01') & (loans['disburse_time'] < '2013-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Albania                                 0.597576
# Armenia                                 3.137134
# Azerbaijan                              1.641617
# Belize                                  0.021129
# Benin                                   0.278361
# Bolivia                                 4.158735
# Botswana                                0.006075
# Brazil                                  0.011656
# Burkina Faso                            0.244456
# Burundi                                 0.830699
# Cambodia                                2.732415
# Cameroon                                0.226118
# Chile                                   0.309723
# Colombia                                2.328418
# Congo                                   0.436574
# Costa Rica                              0.699881
# Cote D'Ivoire                           0.052718
# Dominican Republic                      0.774943
# Ecuador                                 2.612456
# ...

# %%
loans[(loans['disburse_time'] >= '2014-01-01') & (loans['disburse_time'] <= '2014-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2014-01-01') & (loans['disburse_time'] < '2014-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Albania                                 0.593405
# Armenia                                 2.156537
# Azerbaijan                              1.092938
# Belize                                  0.070761
# Benin                                   0.308323
# Bolivia                                 3.285669
# Brazil                                  0.043525
# Burkina Faso                            0.336891
# Burundi                                 0.721070
# Cambodia                                2.853198
# Cameroon                                0.078831
# Chile                                   0.012656
# China                                   0.015911
# Colombia                                3.056687
# Congo                                   0.386086
# Costa Rica                              0.375106
# Dominican Republic                      0.498120
# Ecuador                                 2.638894
# Egypt                                   0.022847
# ...

# %%
loans[(loans['disburse_time'] >= '2015-01-01') & (loans['disburse_time'] <= '2015-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2015-01-01') & (loans['disburse_time'] < '2015-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                              0.003855
# Albania                                  0.542467
# Armenia                                  2.261303
# Azerbaijan                               0.555203
# Bolivia                                  4.387436
# Brazil                                   0.032733
# Burkina Faso                             0.562126
# Burundi                                  0.557612
# Cambodia                                 3.247236
# Cameroon                                 0.029649
# Chile                                    0.054560
# China                                    0.099804
# Colombia                                 2.746239
# Congo                                    0.127863
# Costa Rica                               0.490059
# Dominican Republic                       0.407360
# Ecuador                                  2.048220
# Egypt                                    0.223315
# ...

# %%
loans[(loans['disburse_time'] >= '2016-01-01') & (loans['disburse_time'] <= '2016-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2016-01-01') & (loans['disburse_time'] < '2016-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Afghanistan                              0.004982
# Albania                                  0.397971
# Armenia                                  2.713776
# Azerbaijan                               0.211605
# Belize                                   0.006555
# Bolivia                                  3.659606
# Brazil                                   0.194587
# Burkina Faso                             0.667666
# Burundi                                  0.316745
# Cambodia                                 3.376568
# Cameroon                                 0.190897
# China                                    0.078423
# Colombia                                 2.410934
# Costa Rica                               0.300880
# Dominican Republic                       0.287054
# Ecuador                                  3.050870
# Egypt                                    0.315983
# El Salvador                              3.943500
# ...

# %%
loans[(loans['disburse_time'] >= '2017-01-01') & (loans['disburse_time'] <= '2017-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2017-01-01') & (loans['disburse_time'] < '2017-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Albania                                  0.434892
# Armenia                                  1.789856
# Benin                                    0.030140
# Bhutan                                   0.012056
# Bolivia                                  2.886098
# Brazil                                   0.436956
# Burkina Faso                             0.559702
# Burundi                                  0.042377
# Cambodia                                 4.576597
# Cameroon                                 0.440407
# Canada                                   0.030140
# China                                    0.043402
# Colombia                                 1.846158
# Costa Rica                               0.336198
# Cote D'Ivoire                            0.030140
# Dominican Republic                       0.350123
# Ecuador                                  3.250929
# Egypt                                    0.316652
# ...

# %%
loans[(loans['disburse_time'] >= '2018-01-01') & (loans['disburse_time'] <= '2018-12-31')].groupby('country_name')['loan_amount'].sum()*100/loans[(loans['disburse_time'] > '2018-01-01') & (loans['disburse_time'] < '2018-12-31')].groupby('loan_amount')['loan_amount'].sum().sum()
# Out:
# country_name
# Belize                               0.424232
# Bolivia                              0.881291
# Brazil                               2.272670
# Cameroon                             5.267544
# Colombia                             0.505038
# Costa Rica                           0.156562
# Dominican Republic                   0.994924
# Ghana                                7.542739
# Guatemala                            0.353526
# Haiti                                3.328199
# India                                2.020151
# Indonesia                            0.348476
# Kenya                               39.731320
# Kyrgyzstan                           0.808060
# Lao People's Democratic Republic     0.613621
# Malawi                               0.212116
# Mali                                 5.050378
# Mexico                               0.047979
# Moldova                              1.583293
# Mozambique                           5.439257
# ...

# %%
### punto 8
#importare loans, implementare punto 1
world_cup = pd.merge(loans_lenders, loans['funded_amount'], left_on =loans_lenders['loan_id'], right_on = loans['loan_id'], how = 'right')
world_cup = world_cup.drop('key_0', axis = 1)
div = (world_cup.groupby('loan_id')['level_1'].max() +1).reset_index()
world_cup = pd.merge(div, world_cup, left_on = div['loan_id'], right_on = world_cup['loan_id'], how = 'right')
world_cup = world_cup.drop('key_0', axis = 1)
world_cup = world_cup.drop('loan_id_x', axis = 1)
world_cup['funded_amount'] = world_cup['funded_amount']/world_cup['level_1_x']
world_cup.groupby(0)['level_1_x'].sum()
# Out:
# 0
#  000               2254.0
#  00000             1524.0
#  0002              1011.0
#  00mike00            38.0
#  0101craign0101    4336.0
#  0132575            147.0
#  0154884             85.0
#  0161130             73.0
#  0169713             74.0
#  0185429             66.0
#  0197462             19.0
#  0206338             53.0
#  0219854             84.0
#  0221581             29.0
#  0239059             57.0
#  0245597              6.0
#  0256321             79.0
#  0265562             38.0
#  0279282             10.0
#  0288537             11.0
#  0295920             43.0
#  0307987            124.0
#  0312857             40.0
#  0321212             57.0
#  0326lsw           1430.0
#  0332772             51.0
#  0346439             36.0
#  0353400             23.0
#  0367630             36.0
#  0376099             22.0
#                     ...
# zuzana5790           34.0
# zuzana7522           13.0
# zuzana8241           19.0
# zuzana8342           46.0
# ...

# %%
### punto 9
avarage= loans.groupby('funded_amount')['funded_amount'].sum().sum()/loans.groupby('country_name')['country_name'].count().count()
pd.DataFrame(avarage-loans.groupby('country_name')['loan_amount'].sum())
# Out:
#                                        loan_amount
# country_name
# Afghanistan                           9.804812e+06
# Albania                               7.465412e+06
# Armenia                              -1.117771e+07
# Azerbaijan                           -3.011863e+06
# Belize                                1.162259e+07
# Benin                                 7.906937e+06
# Bhutan                                1.175276e+07
# Bolivia                              -3.245396e+07
# Bosnia and Herzegovina                1.129551e+07
# Botswana                              1.176476e+07
# Brazil                                1.058044e+07
# Bulgaria                              1.139746e+07
# Burkina Faso                          7.687562e+06
# Burundi                               6.539312e+06
# Cambodia                             -3.984076e+07
# Cameroon                              9.521962e+06
# Canada                                1.172276e+07
# ...

# %%
## punto 10
country_stats = pd.read_csv('C:\\Users\\Enrico\\Documents\\UNIMIB\\Foundations of Computer Science\\Project_comp_science\\country_stats.csv')
c_s= country_stats[['country_name', 'population', 'population_below_poverty_line']]
# prendere avarage dal punto precedente
loans2 = pd.DataFrame(avarage-loans.groupby('country_name')['loan_amount'].sum())
loans2['country_name2']= loans2.index
merge10 = pd.merge(c_s,loans2, left_on = 'country_name', right_on = 'country_name2', how='inner')
merge10 = merge10.drop('country_name2', axis=1)
merge10['ratio1']=merge10['loan_amount']/merge10['population']
#per loan amount si intende la differenza e non l'originale loan amount
# per index si intende il nome del paese
merge10.groupby('country_name')['ratio1'].max().idxmax()
# oppure
# merge10[['country_name', 'ratio1']].sort_values('ratio1',ascending=False)
# Out:
# 'Belize'

# %%
## punto 11
#implementare il punto 10
merge10['not_below'] = merge10['population'] *(1 - merge10['population_below_poverty_line']/100)
merge10['ratio2'] = merge10['loan_amount']/merge10['not_below']
merge10.groupby('country_name')['ratio2'].max().idxmax()
#oppure
#merge10.groupby('country_name')['ratio2'].max()
# Out:
# 'Suriname'

# %%
## punto 12
#implementare punto due
loans3 = loans[['loan_id','disburse_time', 'planned_expiration_time', 'funded_amount','duration']]
loans3 = loans3[loans3.loc[:,'duration'] >= 0]

loans3['disburse_yday_rev'] = 365 - loans3['disburse_time'].dt.dayofyear
loans3['expiration_yday'] = loans3['planned_expiration_time'].dt.dayofyear

loans3['2011a'] = loans3.loc[loans3['disburse_time'].dt.year == 2011, 'disburse_yday_rev']/loans3['duration']
loans3['2012a'] = loans3.loc[loans3['disburse_time'].dt.year == 2012, 'disburse_yday_rev']/loans3['duration']
loans3['2013a'] = loans3.loc[loans3['disburse_time'].dt.year == 2013, 'disburse_yday_rev']/loans3['duration']
loans3['2014a'] = loans3.loc[loans3['disburse_time'].dt.year == 2014, 'disburse_yday_rev']/loans3['duration']
loans3['2015a'] = loans3.loc[loans3['disburse_time'].dt.year == 2015, 'disburse_yday_rev']/loans3['duration']
loans3['2016a'] = loans3.loc[loans3['disburse_time'].dt.year == 2016, 'disburse_yday_rev']/loans3['duration']
loans3['2017a'] = loans3.loc[loans3['disburse_time'].dt.year == 2017, 'disburse_yday_rev']/loans3['duration']
loans3['2018a'] = loans3.loc[loans3['disburse_time'].dt.year == 2018, 'disburse_yday_rev']/loans3['duration']

loans3.loc[loans3['2012a'] > 1, '2012a'] = 1
loans3.loc[loans3['2013a'] > 1, '2013a'] = 1
loans3.loc[loans3['2014a'] > 1, '2014a'] = 1
loans3.loc[loans3['2015a'] > 1, '2015a'] = 1
loans3.loc[loans3['2016a'] > 1, '2016a'] = 1
loans3.loc[loans3['2017a'] > 1, '2017a'] = 1
loans3.loc[loans3['2018a'] > 1, '2018a'] = 1

loans3.loc[loans3['2011a'].isna(), '2011a'] = 0
loans3.loc[loans3['2012a'].isna(), '2012a'] = 0
loans3.loc[loans3['2013a'].isna(), '2013a'] = 0
loans3.loc[loans3['2014a'].isna(), '2014a'] = 0
loans3.loc[loans3['2015a'].isna(), '2015a'] = 0
loans3.loc[loans3['2016a'].isna(), '2016a'] = 0
loans3.loc[loans3['2017a'].isna(), '2017a'] = 0
loans3.loc[loans3['2018a'].isna(), '2018a'] = 0

loans3['2012b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2012, 'expiration_yday']/loans3['duration']
loans3['2013b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2013, 'expiration_yday']/loans3['duration']
loans3['2014b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2014, 'expiration_yday']/loans3['duration']
loans3['2015b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2015, 'expiration_yday']/loans3['duration']
loans3['2016b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2016, 'expiration_yday']/loans3['duration']
loans3['2017b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2017, 'expiration_yday']/loans3['duration']
loans3['2018b'] = loans3.loc[loans3['planned_expiration_time'].dt.year == 2018, 'expiration_yday']/loans3['duration']

loans3.loc[loans3['2012b'] > 1, '2012b'] = 1
loans3.loc[loans3['2013b'] > 1, '2013b'] = 1
loans3.loc[loans3['2014b'] > 1, '2014b'] = 1
loans3.loc[loans3['2015b'] > 1, '2015b'] = 1
loans3.loc[loans3['2016b'] > 1, '2016b'] = 1
loans3.loc[loans3['2017b'] > 1, '2017b'] = 1
loans3.loc[loans3['2018b'] > 1, '2018b'] = 1

loans3.loc[loans3['2012b'].isna(), '2012b'] = 0
loans3.loc[loans3['2013b'].isna(), '2013b'] = 0
loans3.loc[loans3['2014b'].isna(), '2014b'] = 0
loans3.loc[loans3['2015b'].isna(), '2015b'] = 0
loans3.loc[loans3['2016b'].isna(), '2016b'] = 0
loans3.loc[loans3['2017b'].isna(), '2017b'] = 0
loans3.loc[loans3['2018b'].isna(), '2018b'] = 0

loans3['2011'] = loans3['2011a']
loans3['2012'] = loans3['2012a'] + loans3['2012b']
loans3['2013'] = loans3['2013a'] + loans3['2013b']
loans3['2014'] = loans3['2014a'] + loans3['2014b']
loans3['2015'] = loans3['2015a'] + loans3['2015b']
loans3['2016'] = loans3['2016a'] + loans3['2016b']
loans3['2017'] = loans3['2017a'] + loans3['2017b']
loans3['2018'] = loans3['2018a'] + loans3['2018b']

loans3.loc[loans3['2012'] > 1, '2012'] = 1
loans3.loc[loans3['2013'] > 1, '2013'] = 1
loans3.loc[loans3['2014'] > 1, '2014'] = 1
loans3.loc[loans3['2015'] > 1, '2015'] = 1
loans3.loc[loans3['2016'] > 1, '2016'] = 1
loans3.loc[loans3['2017'] > 1, '2017'] = 1
loans3.loc[loans3['2018'] > 1, '2018'] = 1

loans3['1-sum'] = 1 - loans3['2011'] - loans3['2012'] - loans3['2013'] - loans3['2014'] - loans3['2015'] - loans3['2016'] - loans3['2017'] - loans3['2018']

loans3.loc[loans3['duration'] > 366, ['2013','2014','2015']] = loans3['1-sum']/3
loans3.loc[loans3['duration'] > 1640, ['2012','2013','2014','2015']] = loans3['1-sum']/4

loans3['2011'] = loans3['2011'] * loans3['funded_amount']
loans3['2012'] = loans3['2012'] * loans3['funded_amount']
loans3['2013'] = loans3['2013'] * loans3['funded_amount']
loans3['2014'] = loans3['2014'] * loans3['funded_amount']
loans3['2015'] = loans3['2015'] * loans3['funded_amount']
loans3['2016'] = loans3['2016'] * loans3['funded_amount']
loans3['2017'] = loans3['2017'] * loans3['funded_amount']
loans3['2018'] = loans3['2018'] * loans3['funded_amount']

# %%
#risultatati punto 12
loans3.groupby('2011')['2011'].sum().sum()
# Out:
# 621070.37066729

# %%
loans3.groupby('2012')['2012'].sum().sum()
# Out:
# 108234217.87494674

# %%
loans3.groupby('2013')['2013'].sum().sum()
# Out:
# 120288712.29211609

# %%
loans3.groupby('2014')['2014'].sum().sum()
# Out:
# 145587654.9756561

# %%
loans3.groupby('2015')['2015'].sum().sum()
# Out:
# 148022499.0126555

# %%
loans3.groupby('2016')['2016'].sum().sum()
# Out:
# 144475689.49001497

# %%
loans3.groupby('2017')['2017'].sum().sum()
# Out:
# 156325278.27001575

# %%
loans3.groupby('2018')['2018'].sum().sum()
# Out:
# 3438894.4986080835
